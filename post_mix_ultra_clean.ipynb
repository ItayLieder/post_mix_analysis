# %% [markdown]
# # 🎛️ Post-Mix Processing Pipeline (Ultra Clean)
#
# **Dual-mode audio processing system:**
# - 📄 **Single-file mode**: Traditional stereo mix processing
# - 🎚️ **Stem mode**: 4-stem intelligent processing (drums, bass, vocals, music)
#
# **Features:**
# - 17 BIG variant profiles for different styles
# - 4 mastering styles (neutral, warm, bright, loud)
# - LUFS normalization for streaming
# - Comprehensive analysis and reporting

# %% [markdown]
# ## ⚙️ User Configuration
# **Edit these settings, then run all cells**

# %%
# ============================================
# 🎛️ USER CONFIGURATION
# ============================================

# Processing Mode Selection
RUN_SINGLE_FILE = True      # Traditional single-file processing
RUN_STEM_MASTERING = True    # 4-stem intelligent processing (RECOMMENDED)

# Input Paths
BASE_INPUT_PATH = "/Users/itay/Documents/post_mix_data/professional_mixes/10_configurations_20250901_120434/01_Standard_Mix/"

# Single file path (if RUN_SINGLE_FILE = True)
MIX_SOURCE_PATH = BASE_INPUT_PATH + "mix.wav"

# Stem paths (if RUN_STEM_MASTERING = True)
STEM_PATHS = {
    "drums": BASE_INPUT_PATH + "drums.wav",
    "bass": BASE_INPUT_PATH + "bass.wav", 
    "vocals": BASE_INPUT_PATH + "vocals.wav",
    "music": BASE_INPUT_PATH + "music.wav"
}

# Stem Balance Control (applies to BIG variants)
STEM_GAINS = {
    "drums": 3.0,   # Drum level multiplier
    "bass": 2.8,    # Bass level multiplier
    "vocals": 4.0,  # Vocal level multiplier
    "music": 2.0    # Music level multiplier
}


# Output Control
PROJECT_NAME = "postmix_clean"
CREATE_INDIVIDUAL_STEM_FILES = False  # Set True to save processed stems separately

# Processing Options
MAX_RECOMMENDATIONS = 3  # Number of recommendation-based variants
ENABLE_STREAMING_SIMULATION = True  # Simulate streaming platform processing

print("✅ Configuration loaded!")
print(f"📁 Input: {BASE_INPUT_PATH}")
print(f"🎯 Mode: {'Stem' if RUN_STEM_MASTERING else 'Single-file'} processing")
if RUN_STEM_MASTERING:
    print(f"🎚️ Stem gains: Drums={STEM_GAINS['drums']}, Bass={STEM_GAINS['bass']}, Vocals={STEM_GAINS['vocals']}, Music={STEM_GAINS['music']}")
# Out:
# ✅ Configuration loaded!
# 📁 Input: /Users/itay/Documents/post_mix_data/professional_mixes/10_configurations_20250901_120434/01_Standard_Mix/
# 🎯 Mode: Stem processing
# 🎚️ Stem gains: Drums=3.0, Bass=2.8, Vocals=4.0, Music=2.0

# %% [markdown]
# ## 📦 Load Dependencies

# %%
# Core imports
import os
import json
import numpy as np
import soundfile as sf
from datetime import datetime

# Project modules - only what we actually use
from config import CONFIG
from data_handler import (
    make_workspace, Manifest, write_manifest,
    import_mix, register_input, load_wav, print_audio_summary
)
from analysis import analyze_wav
from render_engine import RenderEngine, StemRenderEngine, RenderOptions, PreprocessConfig
from mastering_orchestrator import MasteringOrchestrator, LocalMasterProvider
from stem_mastering import load_stem_set, validate_stem_set
from logging_versioning import (
    RunLogger, capture_environment, CODE_VERSIONS,
    register_and_log_artifact, make_repro_zip, json_sha256
)
from presets_recommendations import (
    recommend_from_analysis, build_all_variants_plan,
    recommendation_summary
)
from utils import ensure_audio_valid

print("✅ All dependencies loaded")
print(f"📊 Using CONFIG version: {CONFIG.to_dict()['audio']['default_bit_depth']}")
# Out:
# Post-Mix I/O layer loaded: AudioBuffer, load_wav, save_wav, resample_poly, slice_preview, with_suffix, auto_out_path, sha256_file, print_audio_summary.
# Convenience helpers loaded: make_workspace, batch_load_wavs, env_fingerprint, Manifest, write/read_manifest, register_input, register_artifact, import_mix.
# Analysis layer loaded: analyze_wav/analyze_audio_array, analysis_table, plot_spectrum, plot_short_term_loudness, plot_waveform_excerpt, LUFS approx, true-peak approx, stereo & health metrics.
# DSP Primitives Layer loaded:
# - Gain/level: apply_gain_db, normalize_peak, normalize_lufs, measure_peak, measure_rms
# - Filters: highpass_filter, lowpass_filter, bandpass_filter, shelf_filter, peaking_eq, notch_filter, tilt_eq
# - Stereo: mid_side_encode, mid_side_decode, stereo_widener
# - Dynamics: compressor (soft‑knee), transient_shaper
# - Fades: fade_in, fade_out
# - K‑weighting/LUFS approx: k_weight, lufs_integrated_approx
# Patched: render_from_cache now unpacks widen_stereo tuple correctly.
# Processors (Feature Macros) loaded: make_bassier, make_punchier, reduce_mud, add_air, widen_stereo, premaster_prep, build_preview_cache, render_from_cache.
# Stem Mastering module loaded:
# - StemSet dataclass for 4-stem organization
# - STEM_VARIANTS with category-specific dial settings
# - STEM_COMBINATIONS for intelligent stem processing
# - load_stem_set(), validate_stem_set(), create_stem_variants()
# - Compatible with existing single-file pipeline
# Logging · Versioning · Reproducibility layer loaded:
# - RunLogger.start(workspace_root, tag) → logger
# - logger.log_params/metrics/artifact(), logger.write_summary()
# - capture_environment(), file_sha256(), capture_config_snapshot()
# - processing_digest(name, code_versions, params)
# - make_repro_zip(out_zip, workspace_root, logger, env_info, inputs, outputs)
# - register_and_log_artifact(manifest, logger, path, kind, params, stage)
# - CODE_VERSIONS dict (update per layer when you change code)
# Presets & Recommendations layer loaded:
# - PRESETS dict, list_presets(), get_preset(name)
# - recommend_from_analysis(rep) → [Recommendation]
# - build_premaster_plan_from_recs(recs, limit) [legacy]
# - build_all_variants_plan(recs, prefix, top_recommendations) [comprehensive]
# - recommend_mastering_styles_from_metrics(rep)
# - recommendation_summary(recs)
# ✅ All dependencies loaded
# 📊 Using CONFIG version: PCM_24

# %% [markdown]
# ## 🔧 Apply Configuration

# %%
# Apply stem gains to CONFIG if using stem mastering
if RUN_STEM_MASTERING:
    print("🎚️ Applying stem balance configuration...")
    
    # Update CONFIG with user's stem gains
    CONFIG.pipeline.stem_gains.update(STEM_GAINS)
    CONFIG.pipeline.create_individual_stem_files = CREATE_INDIVIDUAL_STEM_FILES
    
    print("✅ Stem gains applied to CONFIG:")
    for stem, gain in STEM_GAINS.items():
        print(f"   {stem}: {gain}x")
else:
    print("📄 Single-file mode - stem gains not applicable")
# Out:
# 🎚️ Applying stem balance configuration...
# ✅ Stem gains applied to CONFIG:
#    drums: 3.0x
#    bass: 2.8x
#    vocals: 4.0x
#    music: 2.0x

# %% [markdown]
# ## 📁 Setup Workspace & Import Audio

# %%
# Setup workspace
print("📁 Setting up workspace...")
workspace_paths = make_workspace(project=PROJECT_NAME)
manifest = Manifest(project=PROJECT_NAME, workspace=workspace_paths)
logger = RunLogger.start(workspace_paths.root, tag=PROJECT_NAME)
environment_info = capture_environment()
logger.log_event("env", {"environment": environment_info})

print(f"✅ Workspace: {workspace_paths.root}")

# Store data for each mode
single_file_data = None
stem_set_data = None
# Out:
# 📁 Setting up workspace...
# Workspace created at: /Users/itay/Documents/post_mix_data/PostMixRuns/postmix_clean_20250901-200541
# ✅ Workspace: /Users/itay/Documents/post_mix_data/PostMixRuns/postmix_clean_20250901-200541

# %%
# Import audio based on selected mode
if RUN_SINGLE_FILE:
    print("📄 Loading single file...")
    
    if not os.path.exists(MIX_SOURCE_PATH):
        raise FileNotFoundError(f"File not found: {MIX_SOURCE_PATH}")
    
    mix_path = import_mix(workspace_paths, MIX_SOURCE_PATH, alias="mix.wav")
    register_input(manifest, mix_path, alias="mix")
    
    audio_data, sample_rate = sf.read(mix_path)
    ensure_audio_valid(audio_data, "input mix")
    
    audio_buffer = load_wav(mix_path)
    print_audio_summary(audio_buffer, "Input Mix")
    
    single_file_data = {
        "audio_data": audio_data,
        "sample_rate": sample_rate,
        "mix_path": mix_path,
        "audio_buffer": audio_buffer
    }
    print("✅ Single file loaded")

if RUN_STEM_MASTERING:
    print("🎛️ Loading stems...")
    
    # Validate stem paths
    valid_stem_paths = {k: v for k, v in STEM_PATHS.items() if v and os.path.exists(v)}
    
    if not valid_stem_paths:
        raise ValueError("No valid stem files found")
    
    print(f"Found {len(valid_stem_paths)} stems: {', '.join(valid_stem_paths.keys())}")
    
    # Load stems
    stem_set = load_stem_set(valid_stem_paths)
    if not validate_stem_set(stem_set):
        raise ValueError("Stem validation failed")
    
    # Register stems
    for stem_type, stem_path in valid_stem_paths.items():
        imported = import_mix(workspace_paths, stem_path, alias=f"{stem_type}.wav")
        register_input(manifest, imported, alias=stem_type)
        register_and_log_artifact(manifest, logger, imported, kind="stem_input",
                                 params={"stem_type": stem_type}, stage="import")
    
    stem_set_data = {
        "stem_set": stem_set,
        "valid_stem_paths": valid_stem_paths,
        "sample_rate": 44100  # Standard rate
    }
    print(f"✅ {len(valid_stem_paths)} stems loaded")
# Out:
# 📄 Loading single file...
# Imported mix → /Users/itay/Documents/post_mix_data/PostMixRuns/postmix_clean_20250901-200541/inputs/mix.wav
# /Users/itay/Documents/GitHub/post_mix_analysis/data_handler.py:160: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, data = wavfile.read(path)
# Input Mix: sr=44100 | ch=2 | dur=358.0s | peak=0.966051 | rms=0.10874
#   path: /Users/itay/Documents/post_mix_data/PostMixRuns/postmix_clean_20250901-200541/inputs/mix.wav
#   sha256: f6e7843d5419f05a...
#   src dtype: float32 | src ch: 2
# ✅ Single file loaded
# 🎛️ Loading stems...
# Found 4 stems: drums, bass, vocals, music
# ✅ Loaded drums stem: 358.0s
# ✅ Loaded bass stem: 358.0s
# ✅ Loaded vocals stem: 358.0s
# ✅ Loaded music stem: 358.0s
# ✅ Found 4 active stems: drums, bass, vocals, music
# ✅ All stems at 44100 Hz
# Imported mix → /Users/itay/Documents/post_mix_data/PostMixRuns/postmix_clean_20250901-200541/inputs/drums.wav
# Imported mix → /Users/itay/Documents/post_mix_data/PostMixRuns/postmix_clean_20250901-200541/inputs/bass.wav
# Imported mix → /Users/itay/Documents/post_mix_data/PostMixRuns/postmix_clean_20250901-200541/inputs/vocals.wav
# Imported mix → /Users/itay/Documents/post_mix_data/PostMixRuns/postmix_clean_20250901-200541/inputs/music.wav
# ✅ 4 stems loaded

# %% [markdown]
# ## 📊 Analysis & Planning

# %%
# Analyze audio and create processing plan
single_file_plan = None
stem_plan = None

if RUN_SINGLE_FILE and single_file_data:
    print("📊 Analyzing single file...")
    
    analysis = analyze_wav(single_file_data["mix_path"])
    
    # Generate recommendations
    recommendations = recommend_from_analysis(analysis)
    print(recommendation_summary(recommendations))
    
    # Build processing plan
    single_file_plan = build_all_variants_plan(
        recommendations, prefix="SF", top_recommendations=MAX_RECOMMENDATIONS
    )
    print(f"✅ Created {len(single_file_plan)} variants")

if RUN_STEM_MASTERING and stem_set_data:
    print("📊 Analyzing stems...")
    
    # Use configured stem combinations (BIG variants)
    stem_plan = CONFIG.pipeline.stem_combinations
    print(f"✅ Using {len(stem_plan)} BIG variant combinations")
    print(f"   Variants: {', '.join([combo[0] for combo in stem_plan[:5]])}...")
# Out:
# 📊 Analyzing single file...
# /Users/itay/Documents/GitHub/post_mix_analysis/analysis.py:285: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sr, data = wavfile.read(path)
# - De-mud & Open Top (priority 1): B28 P30 C18 A25 W8
#     • bass_energy %89.7 is high → reduce mud via clarity + keep lows controlled
#     • air_energy %0.003 is low → add air shelf for brightness
#     • crest 17.8 dB → moderate punch to emphasize transients
#     ↪ Start here if the mix feels boomy/dull.
# - Punch Up the Transients (priority 2): B16 P38 C10 A14 W8
#     • crest 17.8 dB (dynamic) and LUFS -20.3 (quiet) → add transient definition
#     • small air lift to help intelligibility
# - Widen Image (Safe) (priority 4): B14 P14 C10 A12 W19
#     • stereo_width 0.34 is narrow → add width
#     • tone moves kept gentle to avoid destabilizing center
#     ↪ If mono compatibility is critical, keep width ≤ 15.
# ✅ Created 39 variants
# 📊 Analyzing stems...
# ✅ Using 17 BIG variant combinations
#    Variants: Reference_Mix, Standard_Mix, Drum_Heavy, Bass_Heavy, Vocal_Forward...

# %% [markdown]
# ## 🎛️ Pre-Mastering Processing

# %%
# Process variants
all_variant_metadata = []
render_options = RenderOptions(
    target_peak_dbfs=CONFIG.audio.render_peak_target_dbfs,
    bit_depth=CONFIG.audio.default_bit_depth,
    hpf_hz=None,
    save_headroom_first=False
)

# Single-file processing
if RUN_SINGLE_FILE and single_file_plan:
    print("🔧 Processing single-file variants...")
    
    engine = RenderEngine(
        single_file_data["audio_data"],
        single_file_data["sample_rate"],
        preprocess=PreprocessConfig(
            low_cutoff=CONFIG.audio.prep_hpf_hz,
            kick_lo=CONFIG.audio.kick_freq_low,
            kick_hi=CONFIG.audio.kick_freq_high
        )
    )
    engine.preprocess()
    
    output_dir = os.path.join(workspace_paths.outputs, "single_file", "premasters")
    variant_metadata = engine.commit_variants(output_dir, single_file_plan, opts=render_options)
    
    for meta in variant_metadata:
        meta["processing_mode"] = "single_file"
    
    all_variant_metadata.extend(variant_metadata)
    print(f"✅ Created {len(variant_metadata)} single-file variants")

# Stem processing
if RUN_STEM_MASTERING and stem_plan:
    print("🎛️ Processing stem variants...")
    
    engine = StemRenderEngine(
        stem_set_data["stem_set"],
        preprocess=PreprocessConfig(
            low_cutoff=CONFIG.audio.prep_hpf_hz,
            kick_lo=CONFIG.audio.kick_freq_low,
            kick_hi=CONFIG.audio.kick_freq_high
        )
    )
    engine.preprocess_all_stems()
    
    output_dir = os.path.join(workspace_paths.outputs, "stem_mastering", "premasters")
    stem_results = engine.commit_stem_variants(output_dir, stem_plan, opts=render_options)
    
    # Convert to metadata format
    for variant_name, variant_data in stem_results.items():
        meta = {
            "out_path": variant_data["final_mix_path"],
            "variant_name": variant_name,
            "processing_mode": "stem_mastering"
        }
        all_variant_metadata.append(meta)
    
    print(f"✅ Created {len(stem_results)} stem variants")

print(f"\n📊 Total variants ready for mastering: {len(all_variant_metadata)}")
variant_metadata = all_variant_metadata
# Out:
# 🔧 Processing single-file variants...
# ✅ Created 39 single-file variants
# 🎛️ Processing stem variants...
# ✅ Found 4 active stems: drums, bass, vocals, music
# ✅ All stems at 44100 Hz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 46
#      36 print("🎛️ Processing stem variants...")
#      38 engine = StemRenderEngine(
#      39     stem_set_data["stem_set"],
#      40     preprocess=PreprocessConfig(
#    (...)
#      44     )
#      45 )
# ---> 46 engine.preprocess_all_stems()
#      48 output_dir = os.path.join(workspace_paths.outputs, "stem_mastering", "premasters")
#      49 stem_results = engine.commit_stem_variants(output_dir, stem_plan, opts=render_options)
#
# File ~/Documents/GitHub/post_mix_analysis/render_engine.py:236, in StemRenderEngine.preprocess_all_stems(self)
#     234 metadata = {}
#     235 for stem_type, engine in self.stem_engines.items():
# --> 236     metadata[stem_type] = engine.preprocess()
#     237 return metadata
#
# File ~/Documents/GitHub/post_mix_analysis/render_engine.py:53, in RenderEngine.preprocess(self)
#      51 def preprocess(self) -> Dict[str, Any]:
#      52     """Build fast preview cache (low/high split, kick band, envelope)."""
# ---> 53     self.cache = build_preview_cache(
#      54         self.x, self.sr,
#      55         low_cutoff=self.pre_cfg.low_cutoff,
#      56         kick_lo=self.pre_cfg.kick_lo,
#      57         kick_hi=self.pre_cfg.kick_hi
#      58     )
#      59     return {
#      60         "sr": self.sr,
#      61         "n_samples": int(self.x.shape[0]),
#    (...)
#      64         "kick_hi": self.pre_cfg.kick_hi
#      65     }
#
# File ~/Documents/GitHub/post_mix_analysis/processors.py:198, in build_preview_cache(x, sr, low_cutoff, kick_lo, kick_hi)
#     196 high = x - low
#     197 kick = bandpass_filter(x, sr, f_lo=kick_lo, f_hi=kick_hi, order=4)
# --> 198 env = _envelope_detector(_mono(kick), sr, attack_ms=4.0, release_ms=90.0)
#     199 p95 = np.percentile(env, 95) if env.size else 0.0
#     200 env01 = np.zeros_like(env, dtype=np.float32) if p95 <= 1e-9 else np.clip(env / p95, 0.0, 1.0).astype(np.float32)
#
# File ~/Documents/GitHub/post_mix_analysis/processors.py:60, in _envelope_detector(mono, sr, attack_ms, release_ms)
#      58     else:
#      59         prev = a_r*prev + (1 - a_r)*v
# ---> 60     env[i] = prev
#      61 return env
#
# KeyboardInterrupt:

# %% [markdown]
# ## 🎭 Mastering

# %%
# Apply mastering to all variants
print("🎭 Applying mastering...")

orchestrator = MasteringOrchestrator(workspace_paths, manifest)
provider = LocalMasterProvider(bit_depth="PCM_24")

master_results = []
master_paths = []

for i, variant_meta in enumerate(variant_metadata, 1):
    premaster_path = variant_meta["out_path"]
    
    if not os.path.exists(premaster_path):
        continue
    
    variant_name = variant_meta.get("variant_name", os.path.basename(premaster_path).replace(".wav", ""))
    print(f"[{i}/{len(variant_metadata)}] Mastering: {variant_name}")
    
    # Master with 4 styles
    results = orchestrator.run(
        premaster_path=premaster_path,
        providers=[provider],
        styles=None,  # Uses default 4 styles
        out_tag="masters",
        level_match_preview_lufs=-14.0
    )
    
    for result in results:
        master_results.append(result)
        master_paths.append(result.out_path)
        
        # Add -14 LUFS version
        lufs_file = os.path.join(
            os.path.dirname(result.out_path),
            f"{result.style}_-14LUFS.wav"
        )
        if os.path.exists(lufs_file):
            master_paths.append(lufs_file)

print(f"\n✅ Mastering complete!")
print(f"📁 Created {len(variant_metadata)} master folders")
print(f"🎵 Total files: {len(master_paths)}")
# Out:
# 🎭 Applying mastering...
# [1/56] Mastering: SF_Transparent
# 🎭 Creating mastered folder: SF_Transparent/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       loud -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       neutral -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       warm -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       bright -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#   ✅ Created master folder: SF_Transparent/ with 4 styles × 2 versions = 8 files
# [2/56] Mastering: SF_BalancedGentle
# 🎭 Creating mastered folder: SF_BalancedGentle/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       loud -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       neutral -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       warm -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       bright -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#   ✅ Created master folder: SF_BalancedGentle/ with 4 styles × 2 versions = 8 files
# [3/56] Mastering: SF_Bassy
# 🎭 Creating mastered folder: SF_Bassy/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       loud -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       neutral -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       warm -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       bright -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#   ✅ Created master folder: SF_Bassy/ with 4 styles × 2 versions = 8 files
# [4/56] Mastering: SF_DeepBass
# 🎭 Creating mastered folder: SF_DeepBass/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       loud -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       neutral -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       warm -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       bright -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#   ✅ Created master folder: SF_DeepBass/ with 4 styles × 2 versions = 8 files
# [5/56] Mastering: SF_ModernLow-End
# 🎭 Creating mastered folder: SF_ModernLow-End/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       loud -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       neutral -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       warm -14 LUFS: -22.9 → -14.0 LUFS (gain: +8.9 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       bright -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#   ✅ Created master folder: SF_ModernLow-End/ with 4 styles × 2 versions = 8 files
# [6/56] Mastering: SF_Punchy
# 🎭 Creating mastered folder: SF_Punchy/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.5 dBFS)
#       loud -14 LUFS: -22.8 → -14.0 LUFS (gain: +8.8 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       neutral -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.5 dBFS)
#       warm -14 LUFS: -22.7 → -14.0 LUFS (gain: +8.7 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       bright -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#   ✅ Created master folder: SF_Punchy/ with 4 styles × 2 versions = 8 files
# [7/56] Mastering: SF_TightAndPunchy
# 🎭 Creating mastered folder: SF_TightAndPunchy/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       loud -14 LUFS: -22.9 → -14.0 LUFS (gain: +8.9 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       neutral -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.5 dBFS)
#       warm -14 LUFS: -22.8 → -14.0 LUFS (gain: +8.8 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       bright -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#   ✅ Created master folder: SF_TightAndPunchy/ with 4 styles × 2 versions = 8 files
# [8/56] Mastering: SF_AggressivePunch
# 🎭 Creating mastered folder: SF_AggressivePunch/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.3 dBFS)
#       loud -14 LUFS: -22.6 → -14.0 LUFS (gain: +8.6 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.4 dBFS)
#       neutral -14 LUFS: -22.8 → -14.0 LUFS (gain: +8.8 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.3 dBFS)
#       warm -14 LUFS: -22.5 → -14.0 LUFS (gain: +8.5 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.5 dBFS)
#       bright -14 LUFS: -22.9 → -14.0 LUFS (gain: +8.9 dB)
#   ✅ Created master folder: SF_AggressivePunch/ with 4 styles × 2 versions = 8 files
# [9/56] Mastering: SF_Clear
# 🎭 Creating mastered folder: SF_Clear/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       loud -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       neutral -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       warm -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       bright -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#   ✅ Created master folder: SF_Clear/ with 4 styles × 2 versions = 8 files
# [10/56] Mastering: SF_ClarityAndAir
# 🎭 Creating mastered folder: SF_ClarityAndAir/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       loud -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       neutral -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       warm -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       bright -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#   ✅ Created master folder: SF_ClarityAndAir/ with 4 styles × 2 versions = 8 files
# [11/56] Mastering: SF_CrystalClear
# 🎭 Creating mastered folder: SF_CrystalClear/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       loud -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       neutral -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       warm -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       bright -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#   ✅ Created master folder: SF_CrystalClear/ with 4 styles × 2 versions = 8 files
# [12/56] Mastering: SF_Airy
# 🎭 Creating mastered folder: SF_Airy/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       loud -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       neutral -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       warm -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       bright -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#   ✅ Created master folder: SF_Airy/ with 4 styles × 2 versions = 8 files
# [13/56] Mastering: SF_Bright
# 🎭 Creating mastered folder: SF_Bright/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       loud -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       neutral -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       warm -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       bright -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#   ✅ Created master folder: SF_Bright/ with 4 styles × 2 versions = 8 files
# [14/56] Mastering: SF_Sparkle
# 🎭 Creating mastered folder: SF_Sparkle/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       loud -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       neutral -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       warm -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       bright -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#   ✅ Created master folder: SF_Sparkle/ with 4 styles × 2 versions = 8 files
# [15/56] Mastering: SF_Wide
# 🎭 Creating mastered folder: SF_Wide/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       loud -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       neutral -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       warm -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.1 dBFS)
#       bright -14 LUFS: -23.6 → -14.0 LUFS (gain: +9.6 dB)
#   ✅ Created master folder: SF_Wide/ with 4 styles × 2 versions = 8 files
# [16/56] Mastering: SF_WidePop
# 🎭 Creating mastered folder: SF_WidePop/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       loud -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       neutral -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       warm -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       bright -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#   ✅ Created master folder: SF_WidePop/ with 4 styles × 2 versions = 8 files
# [17/56] Mastering: SF_UltraWide
# 🎭 Creating mastered folder: SF_UltraWide/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.1 dBFS)
#       loud -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.1 dBFS)
#       neutral -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       warm -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.2 dBFS)
#       bright -14 LUFS: -23.7 → -14.0 LUFS (gain: +9.7 dB)
#   ✅ Created master folder: SF_UltraWide/ with 4 styles × 2 versions = 8 files
# [18/56] Mastering: SF_WarmAndWide
# 🎭 Creating mastered folder: SF_WarmAndWide/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       loud -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       neutral -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       warm -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       bright -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#   ✅ Created master folder: SF_WarmAndWide/ with 4 styles × 2 versions = 8 files
# [19/56] Mastering: SF_PunchyAndBright
# 🎭 Creating mastered folder: SF_PunchyAndBright/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       loud -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       neutral -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       warm -14 LUFS: -22.9 → -14.0 LUFS (gain: +8.9 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       bright -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#   ✅ Created master folder: SF_PunchyAndBright/ with 4 styles × 2 versions = 8 files
# [20/56] Mastering: SF_BassAndPunch
# 🎭 Creating mastered folder: SF_BassAndPunch/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       loud -14 LUFS: -22.9 → -14.0 LUFS (gain: +8.9 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       neutral -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       warm -14 LUFS: -22.8 → -14.0 LUFS (gain: +8.8 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       bright -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#   ✅ Created master folder: SF_BassAndPunch/ with 4 styles × 2 versions = 8 files
# [21/56] Mastering: SF_ClearAndWide
# 🎭 Creating mastered folder: SF_ClearAndWide/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       loud -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.1 dBFS)
#       neutral -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       warm -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.1 dBFS)
#       bright -14 LUFS: -23.6 → -14.0 LUFS (gain: +9.6 dB)
#   ✅ Created master folder: SF_ClearAndWide/ with 4 styles × 2 versions = 8 files
# [22/56] Mastering: SF_MaximumBass
# 🎭 Creating mastered folder: SF_MaximumBass/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       loud -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       neutral -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       warm -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       bright -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#   ✅ Created master folder: SF_MaximumBass/ with 4 styles × 2 versions = 8 files
# [23/56] Mastering: SF_MaximumPunch
# 🎭 Creating mastered folder: SF_MaximumPunch/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.4 dBFS)
#       loud -14 LUFS: -22.7 → -14.0 LUFS (gain: +8.7 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.4 dBFS)
#       neutral -14 LUFS: -22.8 → -14.0 LUFS (gain: +8.8 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.4 dBFS)
#       warm -14 LUFS: -22.6 → -14.0 LUFS (gain: +8.6 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.5 dBFS)
#       bright -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#   ✅ Created master folder: SF_MaximumPunch/ with 4 styles × 2 versions = 8 files
# [24/56] Mastering: SF_MaximumClarity
# 🎭 Creating mastered folder: SF_MaximumClarity/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.1 dBFS)
#       loud -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.1 dBFS)
#       neutral -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.1 dBFS)
#       warm -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.2 dBFS)
#       bright -14 LUFS: -23.7 → -14.0 LUFS (gain: +9.7 dB)
#   ✅ Created master folder: SF_MaximumClarity/ with 4 styles × 2 versions = 8 files
# [25/56] Mastering: SF_MaximumAir
# 🎭 Creating mastered folder: SF_MaximumAir/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       loud -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       neutral -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       warm -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       bright -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#   ✅ Created master folder: SF_MaximumAir/ with 4 styles × 2 versions = 8 files
# [26/56] Mastering: SF_MaximumWidth
# 🎭 Creating mastered folder: SF_MaximumWidth/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.2 dBFS)
#       loud -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.2 dBFS)
#       neutral -14 LUFS: -23.6 → -14.0 LUFS (gain: +9.6 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.1 dBFS)
#       warm -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.3 dBFS)
#       bright -14 LUFS: -23.8 → -14.0 LUFS (gain: +9.8 dB)
#   ✅ Created master folder: SF_MaximumWidth/ with 4 styles × 2 versions = 8 files
# [27/56] Mastering: SF_HipHop
# 🎭 Creating mastered folder: SF_HipHop/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       loud -14 LUFS: -22.9 → -14.0 LUFS (gain: +8.9 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       neutral -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       warm -14 LUFS: -22.8 → -14.0 LUFS (gain: +8.8 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       bright -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#   ✅ Created master folder: SF_HipHop/ with 4 styles × 2 versions = 8 files
# [28/56] Mastering: SF_Rock
# 🎭 Creating mastered folder: SF_Rock/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       loud -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       neutral -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       warm -14 LUFS: -22.9 → -14.0 LUFS (gain: +8.9 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       bright -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#   ✅ Created master folder: SF_Rock/ with 4 styles × 2 versions = 8 files
# [29/56] Mastering: SF_Electronic
# 🎭 Creating mastered folder: SF_Electronic/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       loud -14 LUFS: -22.9 → -14.0 LUFS (gain: +8.9 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       neutral -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       warm -14 LUFS: -22.8 → -14.0 LUFS (gain: +8.8 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       bright -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#   ✅ Created master folder: SF_Electronic/ with 4 styles × 2 versions = 8 files
# [30/56] Mastering: SF_Jazz
# 🎭 Creating mastered folder: SF_Jazz/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       loud -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       neutral -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       warm -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       bright -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#   ✅ Created master folder: SF_Jazz/ with 4 styles × 2 versions = 8 files
# [31/56] Mastering: SF_Classical
# 🎭 Creating mastered folder: SF_Classical/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       loud -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       neutral -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       warm -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.1 dBFS)
#       bright -14 LUFS: -23.6 → -14.0 LUFS (gain: +9.6 dB)
#   ✅ Created master folder: SF_Classical/ with 4 styles × 2 versions = 8 files
# [32/56] Mastering: SF_Vocal
# 🎭 Creating mastered folder: SF_Vocal/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       loud -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       neutral -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       warm -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       bright -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#   ✅ Created master folder: SF_Vocal/ with 4 styles × 2 versions = 8 files
# [33/56] Mastering: SF_Acoustic
# 🎭 Creating mastered folder: SF_Acoustic/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       loud -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       neutral -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       warm -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.0 dBFS)
#       bright -14 LUFS: -23.5 → -14.0 LUFS (gain: +9.5 dB)
#   ✅ Created master folder: SF_Acoustic/ with 4 styles × 2 versions = 8 files
# [34/56] Mastering: SF_Metal
# 🎭 Creating mastered folder: SF_Metal/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.5 dBFS)
#       loud -14 LUFS: -22.8 → -14.0 LUFS (gain: +8.8 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       neutral -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.5 dBFS)
#       warm -14 LUFS: -22.7 → -14.0 LUFS (gain: +8.7 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       bright -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#   ✅ Created master folder: SF_Metal/ with 4 styles × 2 versions = 8 files
# [35/56] Mastering: SF_AggressiveBass
# 🎭 Creating mastered folder: SF_AggressiveBass/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       loud -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       neutral -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       warm -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       bright -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#   ✅ Created master folder: SF_AggressiveBass/ with 4 styles × 2 versions = 8 files
# [36/56] Mastering: SF_optimized_youtube
# 🎭 Creating mastered folder: SF_optimized_youtube/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       loud -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       neutral -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       warm -14 LUFS: -22.9 → -14.0 LUFS (gain: +8.9 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       bright -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#   ✅ Created master folder: SF_optimized_youtube/ with 4 styles × 2 versions = 8 files
# [37/56] Mastering: SF_De-mudAndOpenTop_recommended
# 🎭 Creating mastered folder: SF_De-mudAndOpenTop_recommended/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       loud -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       neutral -14 LUFS: -23.1 → -14.0 LUFS (gain: +9.1 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       warm -14 LUFS: -22.9 → -14.0 LUFS (gain: +8.9 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.8 dBFS)
#       bright -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#   ✅ Created master folder: SF_De-mudAndOpenTop_recommended/ with 4 styles × 2 versions = 8 files
# [38/56] Mastering: SF_PunchUptheTransients_recommended
# 🎭 Creating mastered folder: SF_PunchUptheTransients_recommended/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       loud -14 LUFS: -22.9 → -14.0 LUFS (gain: +8.9 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       neutral -14 LUFS: -23.0 → -14.0 LUFS (gain: +9.0 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.6 dBFS)
#       warm -14 LUFS: -22.8 → -14.0 LUFS (gain: +8.8 dB)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.7 dBFS)
#       bright -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#   ✅ Created master folder: SF_PunchUptheTransients_recommended/ with 4 styles × 2 versions = 8 files
# [39/56] Mastering: SF_WidenImage(Safe)_recommended
# 🎭 Creating mastered folder: SF_WidenImage(Safe)_recommended/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.2 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 5.9 dBFS)
#       loud -14 LUFS: -23.2 → -14.0 LUFS (gain: +9.2 dB)
#     Mastering input peak: -1.2 dBTP
# ...
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 7.1 dBFS)
#       neutral -14 LUFS: -24.6 → -14.0 LUFS (gain: +10.6 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 7.0 dBFS)
#       warm -14 LUFS: -24.4 → -14.0 LUFS (gain: +10.4 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 7.2 dBFS)
#       bright -14 LUFS: -24.7 → -14.0 LUFS (gain: +10.7 dB)
#   ✅ Created master folder: Vocal_Forward/ with 4 styles × 2 versions = 8 files
# [45/56] Mastering: Wide_Stereo
# 🎭 Creating mastered folder: Wide_Stereo/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 7.1 dBFS)
#       loud -14 LUFS: -24.5 → -14.0 LUFS (gain: +10.5 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 7.2 dBFS)
#       neutral -14 LUFS: -24.6 → -14.0 LUFS (gain: +10.6 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 7.1 dBFS)
#       warm -14 LUFS: -24.4 → -14.0 LUFS (gain: +10.4 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 7.2 dBFS)
#       bright -14 LUFS: -24.7 → -14.0 LUFS (gain: +10.7 dB)
#   ✅ Created master folder: Wide_Stereo/ with 4 styles × 2 versions = 8 files
# [46/56] Mastering: Radio_Ready
# 🎭 Creating mastered folder: Radio_Ready/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       loud -14 LUFS: -24.0 → -14.0 LUFS (gain: +10.0 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       neutral -14 LUFS: -24.2 → -14.0 LUFS (gain: +10.2 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       warm -14 LUFS: -24.0 → -14.0 LUFS (gain: +10.0 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.8 dBFS)
#       bright -14 LUFS: -24.3 → -14.0 LUFS (gain: +10.3 dB)
#   ✅ Created master folder: Radio_Ready/ with 4 styles × 2 versions = 8 files
# [47/56] Mastering: Club_Energy
# 🎭 Creating mastered folder: Club_Energy/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.1 dBFS)
#       loud -14 LUFS: -23.4 → -14.0 LUFS (gain: +9.4 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.1 dBFS)
#       neutral -14 LUFS: -23.6 → -14.0 LUFS (gain: +9.6 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.1 dBFS)
#       warm -14 LUFS: -23.3 → -14.0 LUFS (gain: +9.3 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.2 dBFS)
#       bright -14 LUFS: -23.7 → -14.0 LUFS (gain: +9.7 dB)
#   ✅ Created master folder: Club_Energy/ with 4 styles × 2 versions = 8 files
# [48/56] Mastering: Modern_Pop
# 🎭 Creating mastered folder: Modern_Pop/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.8 dBFS)
#       loud -14 LUFS: -24.1 → -14.0 LUFS (gain: +10.1 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.8 dBFS)
#       neutral -14 LUFS: -24.3 → -14.0 LUFS (gain: +10.3 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.8 dBFS)
#       warm -14 LUFS: -24.1 → -14.0 LUFS (gain: +10.1 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.9 dBFS)
#       bright -14 LUFS: -24.4 → -14.0 LUFS (gain: +10.4 dB)
#   ✅ Created master folder: Modern_Pop/ with 4 styles × 2 versions = 8 files
# [49/56] Mastering: Rock_Power
# 🎭 Creating mastered folder: Rock_Power/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 7.3 dBFS)
#       loud -14 LUFS: -24.6 → -14.0 LUFS (gain: +10.6 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 7.3 dBFS)
#       neutral -14 LUFS: -24.8 → -14.0 LUFS (gain: +10.8 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 7.3 dBFS)
#       warm -14 LUFS: -24.6 → -14.0 LUFS (gain: +10.6 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 7.4 dBFS)
#       bright -14 LUFS: -24.9 → -14.0 LUFS (gain: +10.9 dB)
#   ✅ Created master folder: Rock_Power/ with 4 styles × 2 versions = 8 files
# [50/56] Mastering: Intimate_Power
# 🎭 Creating mastered folder: Intimate_Power/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.8 dBFS)
#       loud -14 LUFS: -24.1 → -14.0 LUFS (gain: +10.1 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.8 dBFS)
#       neutral -14 LUFS: -24.2 → -14.0 LUFS (gain: +10.2 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.2 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.8 dBFS)
#       warm -14 LUFS: -24.0 → -14.0 LUFS (gain: +10.0 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.9 dBFS)
#       bright -14 LUFS: -24.4 → -14.0 LUFS (gain: +10.4 dB)
#   ✅ Created master folder: Intimate_Power/ with 4 styles × 2 versions = 8 files
# [51/56] Mastering: Maximum_Impact
# 🎭 Creating mastered folder: Maximum_Impact/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.9 dBFS)
#       loud -14 LUFS: -24.2 → -14.0 LUFS (gain: +10.2 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.9 dBFS)
#       neutral -14 LUFS: -24.4 → -14.0 LUFS (gain: +10.4 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       warm -14 LUFS: -24.2 → -14.0 LUFS (gain: +10.2 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 7.0 dBFS)
#       bright -14 LUFS: -24.5 → -14.0 LUFS (gain: +10.5 dB)
#   ✅ Created master folder: Maximum_Impact/ with 4 styles × 2 versions = 8 files
# [52/56] Mastering: Stem_PunchyMix
# 🎭 Creating mastered folder: Stem_PunchyMix/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       loud -14 LUFS: -24.0 → -14.0 LUFS (gain: +10.0 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       neutral -14 LUFS: -24.1 → -14.0 LUFS (gain: +10.1 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       warm -14 LUFS: -24.0 → -14.0 LUFS (gain: +10.0 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.8 dBFS)
#       bright -14 LUFS: -24.3 → -14.0 LUFS (gain: +10.3 dB)
#   ✅ Created master folder: Stem_PunchyMix/ with 4 styles × 2 versions = 8 files
# [53/56] Mastering: Stem_WideAndOpen
# 🎭 Creating mastered folder: Stem_WideAndOpen/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       loud -14 LUFS: -24.0 → -14.0 LUFS (gain: +10.0 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       neutral -14 LUFS: -24.1 → -14.0 LUFS (gain: +10.1 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       warm -14 LUFS: -24.0 → -14.0 LUFS (gain: +10.0 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.8 dBFS)
#       bright -14 LUFS: -24.3 → -14.0 LUFS (gain: +10.3 dB)
#   ✅ Created master folder: Stem_WideAndOpen/ with 4 styles × 2 versions = 8 files
# [54/56] Mastering: Stem_TightAndControlled
# 🎭 Creating mastered folder: Stem_TightAndControlled/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       loud -14 LUFS: -24.0 → -14.0 LUFS (gain: +10.0 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       neutral -14 LUFS: -24.1 → -14.0 LUFS (gain: +10.1 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       warm -14 LUFS: -24.0 → -14.0 LUFS (gain: +10.0 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.8 dBFS)
#       bright -14 LUFS: -24.3 → -14.0 LUFS (gain: +10.3 dB)
#   ✅ Created master folder: Stem_TightAndControlled/ with 4 styles × 2 versions = 8 files
# [55/56] Mastering: Stem_Aggressive
# 🎭 Creating mastered folder: Stem_Aggressive/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       loud -14 LUFS: -24.0 → -14.0 LUFS (gain: +10.0 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       neutral -14 LUFS: -24.1 → -14.0 LUFS (gain: +10.1 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       warm -14 LUFS: -24.0 → -14.0 LUFS (gain: +10.0 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.8 dBFS)
#       bright -14 LUFS: -24.3 → -14.0 LUFS (gain: +10.3 dB)
#   ✅ Created master folder: Stem_Aggressive/ with 4 styles × 2 versions = 8 files
# [56/56] Mastering: Stem_Balanced
# 🎭 Creating mastered folder: Stem_Balanced/ (8 files: 4 styles × 2 versions)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       loud -14 LUFS: -24.0 → -14.0 LUFS (gain: +10.0 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.4 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       neutral -14 LUFS: -24.1 → -14.0 LUFS (gain: +10.1 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.3 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.7 dBFS)
#       warm -14 LUFS: -24.0 → -14.0 LUFS (gain: +10.0 dB)
#     Mastering input peak: -1.4 dBTP
#     Normalized hot input down to -3.5 dBTP
#     Skipped final normalization - peak at -3.5 dBTP is acceptable
#       Applied limiting to prevent clipping (peak was 6.8 dBFS)
#       bright -14 LUFS: -24.3 → -14.0 LUFS (gain: +10.3 dB)
#   ✅ Created master folder: Stem_Balanced/ with 4 styles × 2 versions = 8 files
#
# ✅ Mastering complete!
# 📁 Created 56 master folders
# 🎵 Total files: 448

# %% [markdown]
# ## 📦 Finalize & Create Bundle

# %%
# Create reproducibility bundle
print("📦 Creating reproducibility bundle...")

bundle_path = os.path.join(workspace_paths.reports, "bundles", f"{logger.run_id}.zip")

# Gather inputs
all_inputs = []
if single_file_data:
    all_inputs.append(single_file_data["mix_path"])
if stem_set_data:
    all_inputs.extend(list(stem_set_data["valid_stem_paths"].values()))

# Create bundle
reproducibility_zip = make_repro_zip(
    bundle_path,
    workspace_root=workspace_paths.root,
    run_logger=logger,
    env_info=environment_info,
    inputs=all_inputs,
    outputs=list(set(master_paths)),
    extra_jsons={
        "code_versions": CODE_VERSIONS,
        "configuration": CONFIG.to_dict(),
        "stem_gains": STEM_GAINS if RUN_STEM_MASTERING else None
    },
    readme_text="Post-mix processing with BIG variants and mastering"
)

# Write manifest
write_manifest(manifest)

# Log summary
logger.write_summary({
    "project": PROJECT_NAME,
    "processing_modes": {
        "single_file": RUN_SINGLE_FILE,
        "stem_mastering": RUN_STEM_MASTERING
    },
    "variants_created": len(variant_metadata),
    "masters_created": len(master_paths),
    "stem_gains": STEM_GAINS if RUN_STEM_MASTERING else None
})

print(f"✅ Bundle saved: {bundle_path}")
# Out:
# 📦 Creating reproducibility bundle...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 14
#      11     all_inputs.extend(list(stem_set_data["valid_stem_paths"].values()))
#      13 # Create bundle
# ---> 14 reproducibility_zip = make_repro_zip(
#      15     bundle_path,
#      16     workspace_root=workspace_paths.root,
#      17     run_logger=logger,
#      18     env_info=environment_info,
#      19     inputs=all_inputs,
#      20     outputs=list(set(master_paths)),
#      21     extra_jsons={
#      22         "code_versions": CODE_VERSIONS,
#      23         "configuration": CONFIG.to_dict(),
#      24         "stem_gains": STEM_GAINS if RUN_STEM_MASTERING else None
#      25     },
#      26     readme_text="Post-mix processing with BIG variants and mastering"
#      27 )
#      29 # Write manifest
#      30 write_manifest(manifest)
#
# File ~/Documents/GitHub/post_mix_analysis/logging_versioning.py:245, in make_repro_zip(out_zip_path, workspace_root, run_logger, env_info, inputs, outputs, extra_jsons, readme_text)
#     235 """
#     236 Creates a zip with:
#     237   - logs/events.jsonl, meta/summary.json
#    (...)
#     241 Returns absolute path to the zip.
#     242 """
#     243 os.makedirs(os.path.dirname(os.path.abspath(out_zip_path)), exist_ok=True)
# --> 245 prov_inputs = [capture_file_provenance(p, role="input") for p in inputs]
#     246 prov_outputs = [capture_file_provenance(p, role="output") for p in outputs]
#     248 bundle_meta = {
#     249     "created": _now_iso(),
#     250     "run_id": run_logger.run_id,
#    (...)
#     254     "outputs": prov_outputs,
#     255 }
#
# File ~/Documents/GitHub/post_mix_analysis/logging_versioning.py:245, in <listcomp>(.0)
#     235 """
#     236 Creates a zip with:
#     237   - logs/events.jsonl, meta/summary.json
#    (...)
#     241 Returns absolute path to the zip.
#     242 """
#     243 os.makedirs(os.path.dirname(os.path.abspath(out_zip_path)), exist_ok=True)
# --> 245 prov_inputs = [capture_file_provenance(p, role="input") for p in inputs]
#     246 prov_outputs = [capture_file_provenance(p, role="output") for p in outputs]
#     248 bundle_meta = {
#     249     "created": _now_iso(),
#     250     "run_id": run_logger.run_id,
#    (...)
#     254     "outputs": prov_outputs,
#     255 }
#
# File ~/Documents/GitHub/post_mix_analysis/logging_versioning.py:213, in capture_file_provenance(path, role)
#     209 def capture_file_provenance(path: str, role: str = "input") -> Dict[str, Any]:
#     210     return {
#     211         "role": role,
#     212         "path": os.path.abspath(path),
# --> 213         "sha256": file_sha256(path),
#     214         "bytes": os.path.getsize(path),
#     215         "mtime": int(os.path.getmtime(path)),
#     216     }
#
# File ~/Documents/GitHub/post_mix_analysis/logging_versioning.py:52, in file_sha256(path, bufsize)
#      50 def file_sha256(path: str, bufsize: int = 1<<20) -> str:
#      51     h = hashlib.sha256()
# ---> 52     with open(path, "rb") as f:
#      53         for chunk in iter(lambda: f.read(bufsize), b""):
#      54             h.update(chunk)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/itay/Documents/post_mix_data/professional_mixes/mix_20250901_092454/drums.wav'

# %% [markdown]
# ## 🎉 Summary

# %%
# Final summary
print("="*60)
print("🎉 PROCESSING COMPLETE!")
print("="*60)
print(f"📁 Workspace: {workspace_paths.root}")
print()

if RUN_SINGLE_FILE:
    single_count = len([v for v in variant_metadata if v.get("processing_mode") == "single_file"])
    print(f"📄 Single-file: {single_count} variants")
    print(f"   Location: {workspace_paths.root}/outputs/single_file/")

if RUN_STEM_MASTERING:
    stem_count = len([v for v in variant_metadata if v.get("processing_mode") == "stem_mastering"])
    print(f"🎛️ Stem mastering: {stem_count} variants")
    print(f"   Location: {workspace_paths.root}/outputs/stem_mastering/")
    print(f"   Stem gains applied: {STEM_GAINS}")

print()
print(f"📊 Total variants: {len(variant_metadata)}")
print(f"🎵 Total master files: {len(master_paths)}")
print(f"📦 Bundle: {bundle_path}")
print()
print("✨ Ready for listening!")
